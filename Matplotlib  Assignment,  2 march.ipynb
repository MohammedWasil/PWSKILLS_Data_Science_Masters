# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ##### Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of Matplotlib.
# ##### Ans- Matplotlib is a cross-platform, data visualization and graphical plotting library for Python and its numerical extension NumPy. Matplotlib is used because, it offers a viable open source alternative to MATLAB. Developers can also use matplotlib’s APIs (Application Programming Interfaces) to embed plots in GUI applications.
# ##### Name of five plots that can be plotted using the Pyplot module of Matplotlib are:-
# (i) Line plot
# (ii) Histogram
# (iii) Scatter plot
# (iv) 3D plot
# (v) Counter plot

# %% [markdown]
# ##### Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data plot a scatter plot.
#
# import numpy as np
#
# np.random.seed(3)
#
# x = 3 + np.random.normal(0, 2, 50)
#
# y = 3 + np.random.normal(0, 2, len(x))
#
# Note: Also add title, xlabel, and ylabel to the plot.
# ##### Ans- Scatter plot is a chart that shows the relationship between the two variables.They are  an incredibly powerful chart type alllowing viewers to  immediately understand  a relationship which would to see in almost any other form.

# %%
import numpy as np

np.random.seed(3)

x = 3 + np.random.normal(0, 2, 50)

y = 3 + np.random.normal(0, 2, len(x))

# %%
plt.scatter(x,y)
plt.xlabel("This is x label data")
plt.ylabel("This is y label data")
# Out:
# Text(0, 0.5, 'This is y label data')

# %% [markdown]
# ##### Q3: Why is the subplot() function used? Draw four line plots using the subplot() function. Use the following data:
#
# import numpy as np
#
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
#
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
#
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
#
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])
# ##### Ans- we use subplot because it creates a figure and a grid of subplots with a single call while providing  reasonable control over how the individual plots are created.

# %%
x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([0, 100, 200, 300, 400, 500])
plt.plot(x,y,marker='x',color='r')
plt.subplot()
# Out:
# <AxesSubplot:>

# %%
x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([50, 20, 40, 20, 60, 70])
plt.plot(x,y,marker='*',color='b')
plt.subplot()
# Out:
# <AxesSubplot:>

# %%
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([10, 20, 30, 40, 50, 60])
plt.plot(x,y,marker='*',color='y')
plt.subplot()
# Out:
# <AxesSubplot:>

# %%
x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([200, 350, 250, 550, 450, 150])
plt.plot(x,y,marker='*',color='g')
plt.subplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
# import numpy as np
#
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])
#
# profit = np.array([3000, 8000, 1000, 10000])
# ##### Ans-  A bar plot is graph that represents the category of data with rectangular bars with lengths and heights that is proportional to the values which they represent.
# ##### Bar plot is used when we are showing segments of information.

# %%
company = np.array(["Apple", "Microsoft", "Google", "AMD"])

profit = np.array([3000, 8000, 1000, 10000])
plt.bar(company,profit)
plt.xlabel('company',size=20)
plt.ylabel('profit',size=20)
# Out:
# Text(0, 0.5, 'profit')

# %%
plt.barh(company,profit)
plt.xlabel('company',size=20)
plt.ylabel('profit',size=20)
# Out:
# Text(0, 0.5, 'profit')

# %% [markdown]
# ##### Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
#
# box1 = np.random.normal(100, 10, 200)
#
# box2 = np.random.normal(90, 20, 200
# ##### Ans- A  box plot is also known as Whisker plot is created to display the summary of the set of data values having properties like minimum . first quartile  and  maxixmum.

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)
data=[box1,box2]
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21998990ac0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2199899d0a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x219989907c0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x2199899d670>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x2199899d940>,
# ...
#  'means': []}
